# %%
# !pip install langchain

# %%
import pandas as pd
from IPython.display import display, Markdown, Image
from neo4j_runway.llm.openai import OpenAIDiscoveryLLM, OpenAIDataModelingLLM
from neo4j_runway import Discovery, GraphDataModeler, PyIngest, UserInput

# %%
failedBank_df = pd.read_csv("banklist.csv", encoding='ISO-8859-1', sep=',', on_bad_lines='skip')
USER_GENERATED_INPUT = UserInput(general_description='This dataset contains a list of failed banks in the United States.',
                                column_descriptions={
                                        'Bank Name': 'Name of the failed bank.',
                                        'City': 'City where the failed bank was headquartered.',
                                        'State': 'State where the failed bank was headquartered.',
                                        'Cert': 'FDIC certificate number of the failed bank.',
                                        'Acquiring Institution': 'Name of the institution that acquired the failed bank.',
                                        'Closing Date': 'Date that the failed bank closed.',
                                        'Fund': 'FDIC fund number of the failed bank, which acts as a unique identifier in this data set.'
                                        },
                            use_cases=[
                                "What are patterns among the locations of failed banks?",
                                "What are connections among the acquiring institutions of failed banks?"
                                ]
                            )
disc_llm = OpenAIDiscoveryLLM(base_url="http://localhost:11434/v1", model_name="tinyllama", api_key="ollama", enable_async=False)

disc = Discovery(llm=disc_llm, user_input=USER_GENERATED_INPUT, data=failedBank_df)
disc.run()

modeling_llm = OpenAIDataModelingLLM(base_url="http://localhost:11434/v1", model_name="tinyllama", api_key="ollama")
gdm = GraphDataModeler(llm=modeling_llm, discovery=disc)
# Out:
# Preliminary AnalyziS of the Data:
#
# 1. Summary: The summary of the data shows that there are 569 failed banks in the United States, with a total of 7 distinct categories (Bank Name, City, State, Acquiiring Institution, Closing Date, and Func). The distribution of Bank Name has a count of 569, with a unique number of 436. The distribution of City has a count of 569, with a unique number of 44. The distribution of State has a count of 569, with a unique number of 44. The distribution of Acquiiring Institution has a count of 569, with a unique number of 303. The distribution of Closing Date has a count of 569, with a unique number of 264.
#
# 2. Distribution: The distribution of Bank Name shows that the top 10% of banks are headquartered in Chicago (with 20 occurrences), followed by New York (with 18 occurrences) and Atlanta (with 17 occurrences). The top 10% of Acquiiring Institutions show that No Acquirer is the most common institution, with a total of 31 occurrences.
#
# 3. Distribution: The distribution of Closing Date shows that the top 10% of banks are closed on 30-Oct-09 (with 9 occurrences), followed by 25-Apr-08 (with 7 occurrences) and 30-Sep-09 (with 6 occurrences). The top 10% of Acquiiring Institutions show that No Acquirer is the most common institution, with a total of 264 occurrences.
#
# 4. Patterns: The most frequent pattern among the Bank Name is "The First State Bank", which appears in 3 occurrences and has a total of 1 unique occurrence. The second most frequent pattern is "Chicago", which appears in 2 occurrences and has a total of 1 unique occurrence.
#
# 5. Patterns: The most frequent pattern among the Acquiiring Institution is "No Acquirer", which appears in 31 occurrences and has a total of 31 unique occurrences. The second most frequent pattern is "No Acquirer", which appears in 20 occurrences and has a total of 20 unique occurrences.
#
# 6. Patterns: The most frequent pattern among the Closing Date is "30-Oct-09", which appears in 10 occurrences and has a total of 9 unique occurrences. The second most frequent pattern is "25-Apr-08", which appears in 7 occurrences and has a total of 7 unique occurrences.
#
# 7. Patterns: The most frequent pattern among the Bank Name is "The First State Bank", which appears in 3 occurrences and has a total of 1 unique occurrence. The second most frequent pattern is "Chicago", which appears in 2 occurrences and has a total of 1 unique occurrence.
#
# 8. Patterns: The most frequent pattern among the Acquiiring Institution is "No Acquirer", which appears in 31 occurrences and has a total of 31 unique occurrences. The second most frequent pattern is "No Acquirer", which appears in 20 occurrences and has a total of 20 unique occurrences.
#
# 9. Patterns: The most frequent pattern among the Closing Date is "30-Oct-09", which appears in 10 occurrences and has a total of 9 unique occurrences. The second most frequent pattern is "25-Apr-08", which appears in 7 occurrences and has a total of 7 unique occurrences.
#
# 10. Patterns: The most frequent pattern among the Bank Name is "The First State Bank", which appears in 3 occurrences and has a total of 1 unique occurrence. The second most frequent pattern is "Chicago", which appears in 2 occurrences and has a total of 1 unique occurrence.
#
# 11. Patterns: The most frequent pattern among the Acquiiring Institution is "No Acquirer", which appears in 31 occurrences and has a total of 31 unique occurrences. The second most frequent pattern is "No Acquirer", which appears in 20 occurrences and has a total of 20 unique occurrences.
#
# 12. Patterns: The most frequent pattern among the Closing Date is "30-Oct-09", which appears in 10 occurrences and has a total of 9 unique occurrences. The second most frequent pattern is "25-Apr-08", which appears in 7 occurrences and has a total of 7 unique occurrences.
#
# 13. Patterns: The most frequent pattern among the Bank Name is "The First State Bank", which appears in 3 occurrences and has a total of 1 unique occurrence. The second most frequent pattern is "Chicago", which appears in 2 occurrences and has a total of 1 unique occurrence.
#
# 14. Patterns: The most frequent pattern among the Acquiiring Institution is "No Acquirer", which appears in 31 occurrences and has a total of 31 unique occurrences. The second most frequent pattern is "No Acquirer", which appears in 20 occurrences and has a total of 20 unique occurrences.
#
# 15. Patterns: The most frequent pattern among the Closing Date is "30-Oct-09", which appears in 10 occurrences and has a total of 9 unique occurrences. The second most frequent pattern is "25-Apr-08", which appears in 7 occurrences and has a total of 7 unique occurrences.
#
# 16. Patterns: The most frequent pattern among the Bank Name is "The First State Bank", which appears in 3 occurrences and has a total of 1 unique occurrence. The second most frequent pattern is "Chicago", which appears in 2 occurrences and has a total of 1 unique occurrence.
#
# 17. Patterns: The most frequent pattern among the Acquiying Institution is "No Acquirer", which appears in 31 occurrences and has a total of 31 unique occurrences. The second most frequent pattern is "No Acquirer", which appears in 20 occurrences and has a total of 20 unique occurrences.
#
# 18. Patterns: The most frequent pattern among the Closing Date is "30-Oct-09", which appears in 10 occurrences and has a total of 9 unique occurrences. The second most frequent pattern is "25-Apr-08", which appears in 7 occurrences and has a total of 7 unique occurrences.
#
# 19. Patterns: The most frequent pattern among the Bank Name is "The First State Bank", which appears in 3 occurrences and has a total of 1 unique occurrence. The second most frequent pattern is "Chicago", which appears in 2 occurrences and has a total of 1 unique occurrence.
#
# 20. Patterns: The most frequent pattern among the Acquiying Institution is "No Acquirer", which appears in 31 occurrences and has a total of 31 unique occurrences. The second most frequent pattern is "No Acquirer", which appears in 20 occurrences and has a total of 20 unique occurrences.
#
# 21. Patterns: The most frequent pattern among the Closing Date is "30-Oct-09", which appears in 10 occurrences and has a total of 9 unique occurrences. The second most frequent pattern is "25-Apr-08", which appears in 7 occurrences and has a total of 7 unique occurrences.
#
# 22. Patterns: The most frequent pattern among the Bank Name is "The First State Bank", which appears in 3 occurrences and has a total of 1 unique occurrence. The second most frequent pattern is "Chicago", which appears in 2 occurrences and has a total of 1 unique occurrence.
#
# 23. Patterns: The most frequent pattern among the Acquiying Institution is "No Acquirer", which appears in 31 occurrences and has a total of 31 unique occurrences. The second most frequent pattern is "No Acquirer", which appears in 20 occurrences and has a total of 20 unique occurrences.
#
# 24. Patterns: The most frequent pattern among the Closing Date is "30-Oct-09", which appears in 10 occurrences and has a total of 9 unique occurrences. The second most frequent pattern is "25-Apr-08", which appears in 7 occurrences and has a total of 7 unique occurrences.
#
# 25. Patterns: The most frequent pattern among the Bank Name is "The First State Bank", which appears in 3 occurrences and has a total of 1 unique occurrence. The second most frequent pattern is "Chicago", which appears in 2 occurrences and has a total of 1 unique occurrence.
#
# 26. Patterns: The most frequent pattern among the Acquiying Institution is "No Acquirer", which appears in 31 occurrences and has a total of 31 unique occurrences. The second most frequent pattern is "No Acquirer", which appears in 20 occurrences and has a total of 20 unique occurrences.
#
# 27. Patterns: The most frequent pattern among the Closing Date is "30-Oct-09", which appears in 10 occurrences and has a total of 9 unique occurrences. The second most frequent pattern is "25-Apr-08", which appears in 7 occurrences and has a total of 7 unique occurrences.
#
# 28. Patterns: The most frequent pattern among the Bank Name is "The First State Bank", which appears in 3 occurrences and has a total of 1 unique occurrence. The second most frequent pattern is "Chicago", which appears in 2 occurrences and has a total of 1 unique occurrence.
#
# 29. Patterns: The most frequent pattern among the Acquiying Institution is "No Acquirer", which appears in 31 occurrences and has a total of 31 unique occurrences. The second most frequent pattern is "No Acquirer", which appears in 20 occurrences and has a total of 20 unique occurrences.
#
# 30. Patterns: The most frequent pattern among the Closing Date is "30-Oct-09", which appears in 10 occurrences and has a total of 9 unique occurrences. The second most frequent pattern is "25-Apr-08", which appears in 7 occurrences and has a total of 7 unique occurrences.
#
# 31. Patterns: The most frequent pattern among the Bank Name is "The First State Bank", which appears in 3 occurrences and has a total of 1 unique occurrence. The second most frequent pattern is "Chicago", which appears in 2 occurrences and has a total of 1 unique occurrence.
#
# 32. Patterns: The most frequent pattern among the Acquiying Institution is "No Acquirer", which appears in 31 occurrences and has a total of 31 unique occurrences. The second most frequent pattern is "No Acquirer", which appears in 20 occurrences and has a total of 20 unique occurrences.
#
# 33. Patterns: The most frequent pattern among the Closing Date is "30-Oct-09", which appears in 10 occurrences and has a total of 9 unique occurrences. The second most frequent pattern is "25-Apr-08", which appears in 7 occurrences and has a total of 7 unique occurrences.
#
# 34. Patterns: The most frequent pattern among the Bank Name is "The First State Bank", which appears in 3 occurrences and has a total of 1 unique occurrence. The second most frequent pattern is "Chicago", which appears in 2 occurrences and has a total of 1 unique occurrence.
#
# 35. Patterns: The most frequent pattern among the Acquiying Institution is "No Acquirer", which appears in 31 occurrences and has a total of 31 unique occurrences. The second most frequent pattern is "No Acquirer", which appears in 20 occurrences and has a total of 20 unique occurrences.
#
# 36. Patterns: The most frequent pattern among the Closing Date is "30-Oct-09", which appears in 10 occurrences and has a total of 9 unique occurrences. The second most frequent pattern is "25-Apr-08", which appears in 7 occurrences and has a total of 7 unique occurrences.
#
# 37. Patterns: The most frequent pattern among the Bank Name is "The First State Bank", which appears in 3 occurrences and has a total of 1 unique occurrence. The second most frequent pattern is "Chicago", which appears in 2 occurrences and has a total of 1 unique occurrence.
#
# 38. Patterns: The most frequent pattern among the Acquiying Institution is "No Acquirer", which appears in 31 occurrences and has a total of 31 unique occurrences. The second most frequent pattern is "No Acquirer", which appears in 20 occurrences and has a total of 20 unique occurrences.
#
# 39. Patterns: The most frequent pattern among the Closing Date is "30-Oct-09", which appears in 10 occurrences and has a total of 9 unique occurrences. The second most frequent pattern is "25-Apr-08", which appears in 7 occurrences and has a total of 7 unique occurrences.
#
# 40. Patterns: The most frequent pattern among the Bank Name is "The First State Bank", which appears in 3 occurrences and has a total of 1 unique occurrence. The second most frequent pattern is "Chicago", which appears in 2 occurrences and has a total of 1 unique occurrence.

# %%
gdm.create_initial_model()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 gdm.create_initial_model()
#
# File ~/workspace/book_kg/.venv/lib/python3.10/site-packages/neo4j_runway/modeler/modeler.py:232, in GraphDataModeler.create_initial_model(self, max_retries, use_yaml_data_model)
#     218 def create_initial_model(
#     219     self, max_retries: int = 3, use_yaml_data_model: bool = False
#     220 ) -> Union[DataModel, Dict[str, Any]]:
#     221     """
#     222     Generate the initial model. This must be ran before a model can be interated on.
#     223     You may access this model with the `get_model` method and providing `version=1`.
#    (...)
#     229         A dictionary containing information about the failed generation attempt.
#     230     """
# --> 232     response = self.llm._get_initial_data_model_response(
#     233         discovery_text=self.discovery,
#     234         user_input=self.user_input,
#     235         max_retries=max_retries,
#     236         use_yaml_data_model=use_yaml_data_model,
#     237     )
#     238     if not isinstance(response, DataModel):
#     239         return response
#
# File ~/workspace/book_kg/.venv/lib/python3.10/site-packages/neo4j_runway/llm/base.py:138, in BaseDataModelingLLM._get_initial_data_model_response(self, discovery_text, user_input, max_retries, use_yaml_data_model)
#     132 while not validation["valid"] and part_one_retries < 2:
#     133     formatted_prompt = create_initial_data_model_cot_prompt(
#     134         discovery_text=discovery_text,
#     135         user_input=user_input,
#     136         allowed_features=user_input.allowed_columns,
#     137     )
# --> 138     entity_pool: DataModelEntityPool = self.client.chat.completions.create(
#     139         model=self.model_name,
#     140         response_model=DataModelEntityPool,
#     141         messages=[
#     142             {
#     143                 "role": "system",
#     144                 "content": SYSTEM_PROMPTS["initial_data_model"],
#     145             },
#     146             {"role": "user", "content": formatted_prompt},
#     147         ],
#     148         **self.model_params,
#     149     )
#     150     validation = entity_pool.validate_pool(
#     151         allowed_features=user_input.allowed_columns
#     152     )
#     153     part_one_retries += 1
#
# File ~/workspace/book_kg/.venv/lib/python3.10/site-packages/instructor/client.py:74, in Instructor.create(self, response_model, messages, max_retries, validation_context, **kwargs)
#      64 def create(
#      65     self,
#      66     response_model: Type[T],
#    (...)
#      70     **kwargs,
#      71 ) -> T:
#      72     kwargs = self.handle_kwargs(kwargs)
# ---> 74     return self.create_fn(
#      75         response_model=response_model,
#      76         messages=messages,
#      77         max_retries=max_retries,
#      78         validation_context=validation_context,
#      79         **kwargs,
#      80     )
#
# File ~/workspace/book_kg/.venv/lib/python3.10/site-packages/instructor/patch.py:141, in patch.<locals>.new_create_sync(response_model, validation_context, max_retries, *args, **kwargs)
#     130 @wraps(func)
#     131 def new_create_sync(
#     132     response_model: Type[T_Model] = None,
#    (...)
#     136     **kwargs: T_ParamSpec.kwargs,
#     137 ) -> T_Model:
#     138     response_model, new_kwargs = handle_response_model(
#     139         response_model=response_model, mode=mode, **kwargs
#     140     )
# --> 141     response = retry_sync(
#     142         func=func,
#     143         response_model=response_model,
#     144         validation_context=validation_context,
#     145         max_retries=max_retries,
#     146         args=args,
#     147         kwargs=new_kwargs,
#     148         mode=mode,
#     149     )
#     150     return response
#
# File ~/workspace/book_kg/.venv/lib/python3.10/site-packages/instructor/retry.py:126, in retry_sync(func, response_model, validation_context, args, kwargs, max_retries, strict, mode)
#     123     raise ValueError("max_retries must be an int or a `tenacity.Retrying` object")
#     125 try:
# --> 126     for attempt in max_retries:
#     127         with attempt:
#     128             try:
#
# File ~/workspace/book_kg/.venv/lib/python3.10/site-packages/tenacity/__init__.py:443, in BaseRetrying.__iter__(self)
#     441 retry_state = RetryCallState(self, fn=None, args=(), kwargs={})
#     442 while True:
# --> 443     do = self.iter(retry_state=retry_state)
#     444     if isinstance(do, DoAttempt):
#     445         yield AttemptManager(retry_state=retry_state)
#
# File ~/workspace/book_kg/.venv/lib/python3.10/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/workspace/book_kg/.venv/lib/python3.10/site-packages/tenacity/__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File ~/workspace/book_kg/.venv/lib/python3.10/site-packages/tenacity/__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File ~/.asdf/installs/python/3.10.0/lib/python3.10/concurrent/futures/_base.py:438, in Future.result(self, timeout)
#     436     raise CancelledError()
#     437 elif self._state == FINISHED:
# --> 438     return self.__get_result()
#     440 self._condition.wait(timeout)
#     442 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.asdf/installs/python/3.10.0/lib/python3.10/concurrent/futures/_base.py:390, in Future.__get_result(self)
#     388 if self._exception:
#     389     try:
# --> 390         raise self._exception
#     391     finally:
#     392         # Break a reference cycle with the exception in self._exception
#     393         self = None
#
# File ~/workspace/book_kg/.venv/lib/python3.10/site-packages/instructor/retry.py:132, in retry_sync(func, response_model, validation_context, args, kwargs, max_retries, strict, mode)
#     130     stream = kwargs.get("stream", False)
#     131     response = update_total_usage(response, total_usage)
# --> 132     return process_response(
#     133         response,
#     134         response_model=response_model,
#     135         stream=stream,
#     136         validation_context=validation_context,
#     137         strict=strict,
#     138         mode=mode,
#     139     )
#     140 except (ValidationError, JSONDecodeError) as e:
#     141     logger.debug(f"Error response: {response}")
#
# File ~/workspace/book_kg/.venv/lib/python3.10/site-packages/instructor/process_response.py:147, in process_response(response, response_model, stream, validation_context, strict, mode)
#     141     model = response_model.from_streaming_response(
#     142         response,
#     143         mode=mode,
#     144     )
#     145     return model
# --> 147 model = response_model.from_response(
#     148     response,
#     149     validation_context=validation_context,
#     150     strict=strict,
#     151     mode=mode,
#     152 )
#     154 # ? This really hints at the fact that we need a better way of
#     155 # ? attaching usage data and the raw response to the model we return.
#     156 if isinstance(model, IterableBase):
#
# File ~/workspace/book_kg/.venv/lib/python3.10/site-packages/instructor/function_calls.py:108, in OpenAISchema.from_response(cls, completion, validation_context, strict, mode)
#     105     return cls.parse_functions(completion, validation_context, strict)
#     107 if mode in {Mode.TOOLS, Mode.MISTRAL_TOOLS}:
# --> 108     return cls.parse_tools(completion, validation_context, strict)
#     110 if mode in {Mode.JSON, Mode.JSON_SCHEMA, Mode.MD_JSON}:
#     111     return cls.parse_json(completion, validation_context, strict)
#
# File ~/workspace/book_kg/.venv/lib/python3.10/site-packages/instructor/function_calls.py:181, in OpenAISchema.parse_tools(cls, completion, validation_context, strict)
#     173 @classmethod
#     174 def parse_tools(
#     175     cls: Type[BaseModel],
#    (...)
#     178     strict: Optional[bool] = None,
#     179 ) -> BaseModel:
#     180     message = completion.choices[0].message
# --> 181     assert (
#     182         len(message.tool_calls or []) == 1
#     183     ), "Instructor does not support multiple tool calls, use List[Model] instead."
#     184     tool_call = message.tool_calls[0]  # type: ignore
#     185     assert (
#     186         tool_call.function.name == cls.openai_schema["name"]  # type: ignore[index]
#     187     ), "Tool name does not match"
#
# AssertionError: Instructor does not support multiple tool calls, use List[Model] instead.
